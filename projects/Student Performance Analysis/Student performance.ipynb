# %% [markdown]
# # Student Performance Analysis :
# This data set consists of the marks secured by the students in various subjects.This dataset is available on kaggle website.

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Reading the Student File

# %%
stu=pd.read_csv(r"C:\Users\91876\OneDrive\Desktop\kaggle\student performance\StudentsPerformance.csv")

# %% [markdown]
# Pritning the whole dataset

# %%
stu
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Checking the Bottom 10 rows

# %%
stu.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %% [markdown]
# Checking shape of data

# %%
stu.shape
# Out:
# (1000, 8)

# %% [markdown]
# To print data types of all columns

# %%
stu.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# To print number of dimensions

# %%
stu.ndim
# Out:
# 2

# %% [markdown]
# To print index

# %%
stu.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# to check the size of data

# %%
stu.size
# Out:
# 8000

# %% [markdown]
# To print column names

# %%
stu.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# to pritning information of the dataset

# %%
stu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# To print Statistic summary of all columns

# %%
stu.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %% [markdown]
# Checking null values in dataset

# %%
stu.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# Checking for Duplicated Values

# %%
stu.duplicated().sum()
# Out:
# 0

# %% [markdown]
# To printing unique values

# %%
stu.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# # Exploring and Visualizing Categorical variable

# %%
stu.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.countplot(x='gender',data=stu,palette="Paired")
plt.show()

# %%
stu['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
sns.set_theme(style="dark")
sns.countplot(y='race/ethnicity',data=stu,palette="mako")
plt.show()

# %%
stu['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.set_theme(style="white")
sns.countplot(y='parental level of education',data=stu,palette="pastel")
plt.show()

# %%
stu['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x='lunch',data=stu,palette="viridis")
plt.show()

# %%
stu['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
sns.set_theme(style="whitegrid")
sns.countplot(x='lunch',data=stu,palette="flare")
plt.show()

# %% [markdown]
# # Visualizing Continuous Variable

# %%
sns.distplot(stu['math score'],color='grey')
plt.show()

# %%
sns.distplot(stu['reading score'],kde=False,color='purple',bins=10)
plt.show()

# %%
sns.distplot(stu['writing score'],hist=False,color='red')
plt.show()

# %% [markdown]
# # How much marks females got in Math Subject?

# %%
stu1=stu[stu['gender']=="female"]
stu1.sort_values('math score',ascending=False).head()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 451  female        group E                some college  standard
# 962  female        group E          associate's degree  standard
# 458  female        group E           bachelor's degree  standard
# 114  female        group E           bachelor's degree  standard
# 263  female        group E                 high school  standard
#
#     test preparation course  math score  reading score  writing score
# 451                    none         100             92             97
# 962                    none         100            100            100
# 458                    none         100            100            100
# 114               completed          99            100            100
# 263                    none          99             93             90

# %% [markdown]
# # How much marks males got in Math subject?

# %%
stu2=stu[stu['gender']=="male"]
stu2.sort_values('reading score',ascending=False).head()
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 916   male        group E           bachelor's degree      standard
# 381   male        group C          associate's degree      standard
# 149   male        group E          associate's degree  free/reduced
# 625   male        group D                some college      standard
# 571   male        group A           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 916               completed         100            100            100
# 381               completed          87            100             95
# 149               completed         100            100             93
# 625               completed         100             97             99
# 571                    none          91             96             92

# %% [markdown]
# # Observation For Math Subject
#  In math subject Females got more 100 out of 100 than males. three female students got full score out of 100 and in male only one student got 100 out of 100. Based on this dataset we can say Female are more intelligent than males in math subject.

# %% [markdown]
# # What is the Total reading score in all of  race/ethnicity ?

# %%
stu1 = stu.copy()
stu1.groupby(['race/ethnicity'])['reading score',].sum()
# Out:
#                 reading score
# race/ethnicity
# group A                  5756
# group B                 12797
# group C                 22044
# group D                 18348
# group E                 10224

# %%
stu1.groupby(['race/ethnicity'])['reading score',].sum().plot.bar(color='skyblue',figsize=(8,5))
plt.ylabel('Total Reading Score')
plt.show()

# %% [markdown]
# # What is Total sum of writing score in parental level of education and lunch?

# %%
stu2=stu.copy()
stu2=stu2.pivot_table('writing score',columns=['parental level of education','lunch'],aggfunc='sum')
stu2
# Out:
# parental level of education associate's degree          bachelor's degree  \
# lunch                             free/reduced standard      free/reduced
# writing score                             5084    10433              3046
#
# parental level of education           high school          master's degree  \
# lunch                       standard free/reduced standard    free/reduced
# writing score                   5613         4018     8222            1677
#
# parental level of education          some college          some high school  \
# lunch                       standard free/reduced standard     free/reduced
# writing score                   2788         5033    10525             3515
#
# parental level of education
# lunch                       standard
# writing score                   8100

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='parental level of education',y='writing score',data=stu,hue='lunch',
            order=stu['parental level of education'].value_counts().index,palette='crest')
plt.show()

# %% [markdown]
# # What is the Maximum Score in Math according to extra test course?

# %%
stu3 = stu.copy()
stu3.groupby(['test preparation course'])['math score',].max()
# Out:
#                          math score
# test preparation course
# completed                       100
# none                            100

# %%
stu3.groupby(['test preparation course'])['math score',].max().plot.bar(color='brown',figsize=(8,5))
plt.ylabel('Total math Score')
plt.show()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(stu,hue='lunch')
plt.show()

# %% [markdown]
# # Heat Map

# %%
stu.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(stu.corr(),annot=True,fmt='.2f',cmap='mako')
plt.show()

# %% [markdown]
# # Conclusion:

# %% [raw]
# 1.Female students are more than Male students.
# 2.In Physical Traits highest students are more in Group C and lowest in Group A.
# 3.Most of the student's parents are in Some collage level of education and least has Master's degree.
# 4.Most of the student got Standard lunch and some of got free lunch.
# 5.Less Student has taken extra test prepration course and most of the student has not taken the extra couse.
# 6.All the Continuous variable has a normal distribution.
# 7.In Math Scores Females got highest marks rather than boys.
# 8.All the student got 100 marks in Math rather they have taken the test course or not.
# 9.All the Subject score of students are highly correlated.
